# %%
import os
import glob
import random
filenames = os.listdir('./out')
filenames.sort()  # make sure that the filenames have a fixed order before shuffling
random.seed(230)
random.shuffle(filenames)
split_1 = int(0.8 * len(filenames))
train_filenames = filenames[:split_1]
#dev_filenames = filenames[split_1:split_2]
test_filenames = filenames[split_1:]
print(train_filenames)
# Out:
# ['2_421.tif.txt.txt', '1_290.tif.txt.txt', '1_38.tif.txt.txt', '4_388.tif.txt.txt', '3_426.tif.txt.txt', '3_267.tif.txt.txt', '5_63.tif.txt.txt', '8_49.tif.txt.txt', '4_468.tif.txt.txt', '1_354.tif.txt.txt', '0_107.tif.txt.txt', '7_213.tif.txt.txt', '2_154.tif.txt.txt', '4_164.tif.txt.txt', '9_94.tif.txt.txt', '4_336.tif.txt.txt', '1_513.tif.txt.txt', '1_145.tif.txt.txt', '1_55.tif.txt.txt', '3_243.tif.txt.txt', '3_177.tif.txt.txt', '2_92.tif.txt.txt', '2_165.tif.txt.txt', '7_234.tif.txt.txt', '4_583.tif.txt.txt', '4_235.tif.txt.txt', '7_232.tif.txt.txt', '5_175.tif.txt.txt', '4_617.tif.txt.txt', '2_256.tif.txt.txt', '0_130.tif.txt.txt', '5_72.tif.txt.txt', '1_396.tif.txt.txt', '2_372.tif.txt.txt', '7_197.tif.txt.txt', '3_214.tif.txt.txt', '3_382.tif.txt.txt', '7_176.tif.txt.txt', '9_249.tif.txt.txt', '2_340.tif.txt.txt', '2_130.tif.txt.txt', '4_234.tif.txt.txt', '0_9.tif.txt.txt', '4_77.tif.txt.txt', '3_533.tif.txt.txt', '4_222.tif.txt.txt', '4_479.tif.txt.txt', '8_1.tif.txt.txt', '
# ...

# %%
def writecontents(filename,path):
    for i in filename:
        labels = i.split('_')
        print(labels[0])
    
        if labels[0] == '0':
            file = open('./out/'+i,'r')
            contents = file.read()
            print(contents)
            filename = path+labels[0]+".txt"
            if os.path.exists(filename):
                append_write = 'a'
            else:
                append_write = 'w'
            with open(filename, append_write) as myfile:
                myfile.write(contents)
            file.close()    
        
        elif labels[0] == '1':
            file = open('./out/'+i,'r')
            contents = file.read()
            #print(contents)
            filename = path+labels[0]+".txt"
            if os.path.exists(filename):
                append_write = 'a'
            else:
                append_write = 'w'
            with open(filename, append_write) as myfile:
                myfile.write(contents)
            file.close() 
         
        elif labels[0] == '2':
            file = open('./out/'+i,'r')
            contents = file.read()
            #print(contents)
            
            filename = path+labels[0]+".txt"
            if os.path.exists(filename):
                append_write = 'a'
            else:
                append_write = 'w'
            with open(filename, append_write) as myfile:
                myfile.write(contents)
            file.close() 
            
            
        elif labels[0] == '3':
            file = open('./out/'+i,'r')
            contents = file.read()
            filename = path+labels[0]+".txt"
            if os.path.exists(filename):
                append_write = 'a'
            else:
                append_write = 'w'
            with open(filename, append_write) as myfile:
                myfile.write(contents)
            file.close() 
            
            
            
        elif labels[0] == '4':
            file = open('./out/'+i,'r')
            contents = file.read()
            filename = path+labels[0]+".txt"
            if os.path.exists(filename):
                append_write = 'a'
            else:
                append_write = 'w'
            with open(filename, append_write) as myfile:
                myfile.write(contents)
            file.close() 
            
            
        elif labels[0] == '5':
            file = open('./out/'+i,'r')
            contents = file.read()
            filename = path+labels[0]+".txt"
            if os.path.exists(filename):
                append_write = 'a'
            else:
                append_write = 'w'
            with open(filename, append_write) as myfile:
                myfile.write(contents)
            file.close()     
        
        
        elif labels[0] == '6':
            file = open('./out/'+i,'r')
            contents = file.read()
            filename = path+labels[0]+".txt"
            if os.path.exists(filename):
                append_write = 'a'
            else:
                append_write = 'w'
            with open(filename, append_write) as myfile:
                myfile.write(contents)
            file.close() 
            
        elif labels[0] == '7':
            file = open('./out/'+i,'r')
            contents = file.read()
            filename = path+labels[0]+".txt"
            if os.path.exists(filename):
                append_write = 'a'
            else:
                append_write = 'w'
            with open(filename, append_write) as myfile:
                myfile.write(contents)
            file.close() 
        
        
        elif labels[0] == '8':
            file = open('./out/'+i,'r')
            contents = file.read()
            filename = path+labels[0]+".txt"
            if os.path.exists(filename):
                append_write = 'a'
            else:
                append_write = 'w'
            with open(filename, append_write) as myfile:
                myfile.write(contents)
            file.close()  
            
        elif labels[0] == '9':
            file = open('./out/'+i,'r')
            contents = file.read()
            filename = path+labels[0]+".txt"
            if os.path.exists(filename):
                append_write = 'a'
            else:
                append_write = 'w'
            with open(filename, append_write) as myfile:
                myfile.write(contents)
            file.close()     
 
     
path_training = './train_data/'
writecontents(train_filenames,path_training)
path_test = './test_data/'
writecontents(test_filenames,path_test)
# Out:
# 2
# 1
# 1
# 4
# 3
# 3
# 5
# 8
# 4
# 1
# 0
# mmosmwmuo
#
# .m £530 9.9 a.
#
# 93 wrm
#
# :65...) 9:53... .x...
# £=.L_.._:_7.:::u..:_ :§._..:......._ 573.1.
# 3:11.11... 3:31:51}... 5.... 1 :3...
#
# £2.11... ......=.,..: 1....
# ,.._._........_?..::_3:_ .. =u:.:.=:.:.4.2:
# 3:13.11... u........:.: 1...... 5... .. :3...
# 2. 1:..I. 11;... 3.. 17.132. 2...: 1.5....
# .4: 3.. 1.. .1 4.. 2.1.5.311.» . .52....
# 1.5.2... c... .. 1:. 5.21:1... 7...: 3...
#
# 2:25
# 21.4 3:21:75...=1._._$|I:.x.u.£ 33
# 25.......=.v......5 95.3.32...
# .2... :3 1.3.1.3..
# .2... 12?. z. . 21:74:12.5. A.
# .. .2:727.3...7=1..:1.E.2_ =2
# 2 .: 1:11.. .2215. i... 1...;
# _ _. 1.... .51....3: ............:..u 3...:
# 5.31.3... .,.:..r:.... = 5:11... 2..
# . 71.13;...11; :32... 2..
# 3.3151... n... .11 u... :_ ; =7...
# . .:... 31.71.5711? 3.. .1... .61...
# i... 3 .45.... .:= 2.2; 02...... 7......
# . s. 11...... 3.3.3.3775: .. 2:...
# 52.2.1 9... .15. 733.... 3.. _ ._
# .15.. €513... 1:57. 5:11....
# ...
